# %% [markdown]
# ### Testing `NodeForecastSolar`

# %%
import pandas as pd
from datetime import datetime, timedelta
from eta_utility.connectors.node import NodeForecastSolar
from eta_utility.connectors.forecast_solar import ForecastSolarConnection

from eta_utility.connectors.entso_e import ENTSOEConnection
from eta_utility.connectors.node import NodeEntsoE

from eta_utility.connectors.node import Node

# %%
# Display all rows
pd.set_option('display.max_rows', None)

# Display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### using `data = watts` (default value)

# %%
node_1 = NodeForecastSolar(
    name="east",
    url="https://api.forecast.solar",
    protocol="forecast_solar",
    api_key="87Fpb6aShqa5Hbmf",
    data="watts",
    latitude=49.86381,
    longitude=8.68105,
    declination=[14, 10],
    azimuth=[90, -90],
    kwp=[23.31, 23.31],
)


node_2 = NodeForecastSolar(
    name="east",
    url="https://api.forecast.solar",
    protocol="forecast_solar",
    api_key="87Fpb6aShqa5Hbmf",
    data="watts",
    latitude=49.86381,
    longitude=8.68105,
    declination=[10, 14],
    azimuth=[90, -90],
    kwp=[23.31, 23.31],
)

connector = ForecastSolarConnection(url="https://api.forecast.solar", api_key="87Fpb6aShqa5Hbmf")

nodes = [node_1, node_2]
from_time = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)
to_time = from_time + timedelta(days=1)
interval = timedelta(minutes=15)

res = connector.read_series(from_time, to_time, nodes, interval)
res
# Out:
# D:\Code Repository\ETA\eta-utility\eta_utility\connectors\forecast_solar.py:147: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   previous_time = from_time.floor("15T") if self._api_key != "None" else from_time.floor("h")
# D:\Code Repository\ETA\eta-utility\eta_utility\connectors\forecast_solar.py:154: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   to_time.floor("15T") + timedelta(minutes=15)
#                                    east
#                                       0             0
# 2024-11-04 00:00:00+01:00      0.000000      0.000000
# 2024-11-04 00:15:00+01:00      0.000000      0.000000
# 2024-11-04 00:30:00+01:00      0.000000      0.000000
# 2024-11-04 00:45:00+01:00      0.000000      0.000000
# 2024-11-04 01:00:00+01:00      0.000000      0.000000
# 2024-11-04 01:15:00+01:00      0.000000      0.000000
# ...

# %% [markdown]
# ### using `data = "watthours"`

# %%
node_1 = NodeForecastSolar(
    name="east",
    url="https://api.forecast.solar",
    protocol="forecast_solar",
    api_key="87Fpb6aShqa5Hbmf",
    data="watthours",
    latitude=49.86381,
    longitude=8.68105,
    declination=[14, 10],
    azimuth=[90, -90],
    kwp=[23.31, 23.31],
)


node_2 = NodeForecastSolar(
    name="east",
    url="https://api.forecast.solar",
    protocol="forecast_solar",
    api_key="87Fpb6aShqa5Hbmf",
    data="watthours",
    latitude=49.86381,
    longitude=8.68105,
    declination=[10, 14],
    azimuth=[90, -90],
    kwp=[23.31, 23.31],
)

connector = ForecastSolarConnection(url="https://api.forecast.solar", api_key="87Fpb6aShqa5Hbmf")

nodes = [node_1, node_2]
from_time = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)
to_time = from_time + timedelta(days=1)
interval = timedelta(minutes=15)

res = connector.read_series(from_time, to_time, nodes, interval)
res
# Out:
# D:\Code Repository\ETA\eta-utility\eta_utility\connectors\forecast_solar.py:147: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   previous_time = from_time.floor("15T") if self._api_key != "None" else from_time.floor("h")
# D:\Code Repository\ETA\eta-utility\eta_utility\connectors\forecast_solar.py:154: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   to_time.floor("15T") + timedelta(minutes=15)
#                                    east
#                                       0             0
# 2024-11-04 00:00:00+01:00      0.000000      0.000000
# 2024-11-04 00:15:00+01:00      0.000000      0.000000
# 2024-11-04 00:30:00+01:00      0.000000      0.000000
# 2024-11-04 00:45:00+01:00      0.000000      0.000000
# 2024-11-04 01:00:00+01:00      0.000000      0.000000
# 2024-11-04 01:15:00+01:00      0.000000      0.000000
# ...

# %% [markdown]
# ### using `data = "watthoursperperiod"`

# %%
node_1 = NodeForecastSolar(
    name="east",
    url="https://api.forecast.solar",
    protocol="forecast_solar",
    api_key="87Fpb6aShqa5Hbmf",
    data="watthoursperperiod",
    latitude=49.86381,
    longitude=8.68105,
    declination=[14, 10],
    azimuth=[90, -90],
    kwp=[23.31, 23.31],
)


node_2 = NodeForecastSolar(
    name="east",
    url="https://api.forecast.solar",
    protocol="forecast_solar",
    api_key="87Fpb6aShqa5Hbmf",
    data="watthoursperperiod",
    latitude=49.86381,
    longitude=8.68105,
    declination=[10, 14],
    azimuth=[90, -90],
    kwp=[23.31, 23.31],
)

connector = ForecastSolarConnection(url="https://api.forecast.solar", api_key="87Fpb6aShqa5Hbmf")

nodes = [node_1, node_2]
from_time = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)
to_time = from_time + timedelta(days=1)
interval = timedelta(minutes=15)

res = connector.read_series(from_time, to_time, nodes, interval)
res
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[18], line 35
#      32 to_time = from_time + timedelta(days=1)
#      33 interval = timedelta(minutes=15)
# ---> 35 res = connector.read_series(from_time, to_time, nodes, interval)
#      36 res
#
# File D:\Code Repository\ETA\eta-utility\eta_utility\connectors\forecast_solar.py:237, in ForecastSolarConnection.read_series(self, from_time, to_time, nodes, interval, **kwargs)
#     234 with concurrent.futures.ThreadPoolExecutor() as executor:
#     235     results = executor.map(self._read_node, nodes)
# --> 237 values = pd.concat(results, axis=1, keys=[n.name for n in nodes], sort=False)
#     239 values, _ = self._select_data(values, from_time, to_time)
#     241 values = df_interpolate(values, _interval)
#
# ...

# %% [markdown]
# #### The URL should be like this [https://api.forecast.solar/87Fpb6aShqa5Hbmf/estimate/watthours/period/49/8/10/90/23.31/14/-90/23.31?time=utc](https://api.forecast.solar/87Fpb6aShqa5Hbmf/estimate/watthours/period/49/8/10/90/23.31/14/-90/23.31?time=utc)
#
# `watthours/period` instead of `watthoursperperiod`

# %% [markdown]
# ### using `data = "watthoursperday"`

# %%
node_1 = NodeForecastSolar(
    name="east",
    url="https://api.forecast.solar",
    protocol="forecast_solar",
    api_key="87Fpb6aShqa5Hbmf",
    data="watthoursperday",
    latitude=49.86381,
    longitude=8.68105,
    declination=[14, 10],
    azimuth=[90, -90],
    kwp=[23.31, 23.31],
)


node_2 = NodeForecastSolar(
    name="east",
    url="https://api.forecast.solar",
    protocol="forecast_solar",
    api_key="87Fpb6aShqa5Hbmf",
    data="watthoursperday",
    latitude=49.86381,
    longitude=8.68105,
    declination=[10, 14],
    azimuth=[90, -90],
    kwp=[23.31, 23.31],
)

connector = ForecastSolarConnection(url="https://api.forecast.solar", api_key="87Fpb6aShqa5Hbmf")

nodes = [node_1, node_2]
from_time = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)
to_time = from_time + timedelta(days=1)
interval = timedelta(minutes=15)

res = connector.read_series(from_time, to_time, nodes, interval)
res
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[24], line 35
#      32 to_time = from_time + timedelta(days=1)
#      33 interval = timedelta(minutes=15)
# ---> 35 res = connector.read_series(from_time, to_time, nodes, interval)
#      36 res
#
# File D:\Code Repository\ETA\eta-utility\eta_utility\connectors\forecast_solar.py:237, in ForecastSolarConnection.read_series(self, from_time, to_time, nodes, interval, **kwargs)
#     234 with concurrent.futures.ThreadPoolExecutor() as executor:
#     235     results = executor.map(self._read_node, nodes)
# --> 237 values = pd.concat(results, axis=1, keys=[n.name for n in nodes], sort=False)
#     239 values, _ = self._select_data(values, from_time, to_time)
#     241 values = df_interpolate(values, _interval)
#
# ...

# %% [markdown]
# #### The URL should be like this [https://api.forecast.solar/87Fpb6aShqa5Hbmf/estimate/watthours/day/49/8/14/90/23.31/10/-90/23.31?time=utc](https://api.forecast.solar/87Fpb6aShqa5Hbmf/estimate/watthours/day/49/8/14/90/23.31/10/-90/23.31?time=utc)
#
# `watthours/day` instead of `watthoursperday`

# %% [markdown]
# ### `ENTSOEConnection` `NodeEntsoE`

# %%
node_e = NodeEntsoE(
    name="entsoe",
    url="https://web-api.tp.entsoe.eu/",
    protocol="entsoe",
    bidding_zone="DEU-LUX",
    endpoint="Price",
)

connector_e = ENTSOEConnection(url="https://web-api.tp.entsoe.eu/", api_token="6311229e-363a-44bd-b827-493aa647a388")

from_time = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)
to_time = from_time + timedelta(days=1)
interval = timedelta(minutes=15)

res_e = connector_e.read_series(from_time, to_time, node_e, interval)
res_e
# Out:
#                           entsoe_Price
#                                     60  15
# 2024-11-04 00:00:00+01:00        92.04 NaN
# 2024-11-04 00:15:00+01:00        92.04 NaN
# 2024-11-04 00:30:00+01:00        92.04 NaN
# 2024-11-04 00:45:00+01:00        92.04 NaN
# 2024-11-04 01:00:00+01:00        89.96 NaN
# 2024-11-04 01:15:00+01:00        89.96 NaN
# 2024-11-04 01:30:00+01:00        89.96 NaN
# 2024-11-04 01:45:00+01:00        89.96 NaN
# 2024-11-04 02:00:00+01:00        90.07 NaN
# 2024-11-04 02:15:00+01:00        90.07 NaN
# 2024-11-04 02:30:00+01:00        90.07 NaN
# 2024-11-04 02:45:00+01:00        90.07 NaN
# 2024-11-04 03:00:00+01:00        89.86 NaN
# 2024-11-04 03:15:00+01:00        89.86 NaN
# 2024-11-04 03:30:00+01:00        89.86 NaN
# 2024-11-04 03:45:00+01:00        89.86 NaN
# 2024-11-04 04:00:00+01:00        90.80 NaN
# 2024-11-04 04:15:00+01:00        90.80 NaN
# 2024-11-04 04:30:00+01:00        90.80 NaN
# 2024-11-04 04:45:00+01:00        90.80 NaN
# ...
